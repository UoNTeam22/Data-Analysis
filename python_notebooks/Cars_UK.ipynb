# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %%
df = pd.read_csv("Cars.csv")
df
# Out:
#     Years  Amount in Millions
# 0    2000                27.2
# 1    2002                28.5
# 2    2004                29.4
# 3    2006                29.9
# 4    2008                30.3
# 5    2010                30.3
# 6    2012                30.5
# 7    2014                30.5
# 8    2016                31.8
# 9    2018                32.5
# 10   2020                32.7

# %%
df = df.dropna()

# %%
X = df['Years']
Y = df['Amount in Millions']

# %%
plt.plot(X,Y)
plt.title('Number of licensed cars in UK')
plt.xlabel('Years')
plt.ylabel('Cars in Millions')
plt.show()

# %%
outer = []
for i in range(len(Y)):
    for x, y in zip(X, Y):
        outer.append([x, y])

# %%
dt = np.array(outer)
x = dt[:, 0]
y = dt[:, 1]

# %%
theta = np.polyfit(x, y, 1)

print(f'The parameters of the line: {theta}')

# Now, calculating the y-axis values against x-values according to
# the parameters theta0, theta1 and theta2
y_line = theta[1] + theta[0] * x

# Plotting the data points and the best fit line
plt.scatter(x, y)
plt.plot(x, y_line, 'r')
plt.title('Number of cars increase over the years')
plt.xlabel('Years')
plt.ylabel('Cars in Millions')

plt.show()
# Out:
# The parameters of the line: [ 2.36818182e-01 -4.45677273e+02]
