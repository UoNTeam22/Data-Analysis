# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %%
df = pd.read_csv("Global_Temperature_Annually.csv")
df
# Out:
#      year  temp_c
# 0    1880   13.79
# 1    1881   13.87
# 2    1882   13.84
# 3    1883   13.81
# 4    1884   13.73
# ..    ...     ...
# 130  2010   14.66
# 131  2011   14.55
# 132  2012   14.57
# 133  2013   14.60
# 134  2014   14.68
#
# [135 rows x 2 columns]

# %%
df = df.dropna()

# %%
X = df['year']
Y = df['temp_c']

# %%
plt.plot(X,Y)
plt.title('Global Temperature Annually')
plt.xlabel('Years')
plt.ylabel('Temperature in Celsius')
plt.show()

# %%
outer = []
for i in range(len(Y)):
    for x, y in zip(X, Y):
        outer.append([x, y])

# %%
dt = np.array(outer)
x = dt[:, 0]
y = dt[:, 1]

# %%
theta = np.polyfit(x, y, 1)

print(f'The parameters of the line: {theta}')

# Now, calculating the y-axis values against x-values according to
# the parameters theta0, theta1 and theta2
y_line = theta[1] + theta[0] * x

# Plotting the data points and the best fit line
plt.scatter(x, y)
plt.plot(x, y_line, 'r')
plt.title('Global Temperature Annually')
plt.xlabel('Years')
plt.ylabel('Temperature in Celsius')

plt.show()
# Out:
# The parameters of the line: [0.00661345 1.11968236]
