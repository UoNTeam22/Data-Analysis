# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %%
df = pd.read_csv("CO2_Fuels.csv")
df
# Out:
#    Year   Coal    Oil   Gas  Cement  Other  Total
# 0  1960   5.15   3.13  0.83    0.16   0.12   9.39
# 1  1970   5.70   6.80  1.79    0.29   0.32  14.90
# 2  1980   7.05   8.96  2.72    0.40   0.36  19.49
# 3  1990   8.71   9.22  3.84    0.50   0.48  22.75
# 4  2000   9.01  10.28  4.73    0.72   0.48  25.22
# 5  2010  13.97  11.31  6.21    1.25   0.61  33.35
# 6  2020  13.98  11.07  7.40    1.63   0.73  34.81

# %%
df = df.dropna()

# %%
X = df['Year']
Y = df['Coal']

# %%
plt.plot(X,Y)
plt.title('Annual CO2 emission from Coal')
plt.xlabel('Years')
plt.ylabel('GtCO2')
plt.show()

# %%
outer = []
for i in range(len(Y)):
    for x, y in zip(X, Y):
        outer.append([x, y])

# %%
dt = np.array(outer)
x = dt[:, 0]
y = dt[:, 1]

# %%
theta = np.polyfit(x, y, 1)

print(f'The parameters of the line: {theta}')

# Now, calculating the y-axis values against x-values according to
# the parameters theta0, theta1 and theta2
y_line = theta[1] + theta[0] * x

# Plotting the data points and the best fit line
plt.scatter(x, y)
plt.plot(x, y_line, 'r')
plt.title('Annual CO2 emission from Coal')
plt.xlabel('Years')
plt.ylabel('GtCO2')

plt.show()
# Out:
# The parameters of the line: [ 1.60678571e-01 -3.10668929e+02]

# %%
X = df['Year']
Y = df['Oil']

plt.plot(X,Y)
plt.title('Annual CO2 emission from Oil')
plt.xlabel('Years')
plt.ylabel('GtCO2')
plt.show()

outer = []
for i in range(len(Y)):
    for x, y in zip(X, Y):
        outer.append([x, y])

dt = np.array(outer)
x = dt[:, 0]
y = dt[:, 1]

theta = np.polyfit(x, y, 1)

print(f'The parameters of the line: {theta}')

# Now, calculating the y-axis values against x-values according to
# the parameters theta0, theta1 and theta2
y_line = theta[1] + theta[0] * x

# Plotting the data points and the best fit line
plt.scatter(x, y)
plt.plot(x, y_line, 'r')
plt.title('Annual CO2 emission from Oil')
plt.xlabel('Years')
plt.ylabel('GtCO2')

plt.show()
# Out:
# The parameters of the line: [ 1.22000000e-01 -2.34098571e+02]

# %%
X = df['Year']
Y = df['Gas']

plt.plot(X,Y)
plt.title('Annual CO2 emission from Gas')
plt.xlabel('Years')
plt.ylabel('GtCO2')
plt.show()

outer = []
for i in range(len(Y)):
    for x, y in zip(X, Y):
        outer.append([x, y])

dt = np.array(outer)
x = dt[:, 0]
y = dt[:, 1]

theta = np.polyfit(x, y, 1)

print(f'The parameters of the line: {theta}')

# Now, calculating the y-axis values against x-values according to
# the parameters theta0, theta1 and theta2
y_line = theta[1] + theta[0] * x

# Plotting the data points and the best fit line
plt.scatter(x, y)
plt.plot(x, y_line, 'r')
plt.title('Annual CO2 emission from Gas')
plt.xlabel('Years')
plt.ylabel('GtCO2')

plt.show()
# Out:
# The parameters of the line: [ 1.09142857e-01 -2.13262857e+02]

# %%
X = df['Year']
Y = df['Cement']

plt.plot(X,Y)
plt.title('Annual CO2 emission from Cement')
plt.xlabel('Years')
plt.ylabel('GtCO2')
plt.show()

outer = []
for i in range(len(Y)):
    for x, y in zip(X, Y):
        outer.append([x, y])

dt = np.array(outer)
x = dt[:, 0]
y = dt[:, 1]

theta = np.polyfit(x, y, 1)

print(f'The parameters of the line: {theta}')

# Now, calculating the y-axis values against x-values according to
# the parameters theta0, theta1 and theta2
y_line = theta[1] + theta[0] * x

# Plotting the data points and the best fit line
plt.scatter(x, y)
plt.plot(x, y_line, 'r')
plt.title('Annual CO2 emission from Cement')
plt.xlabel('Years')
plt.ylabel('GtCO2')

plt.show()
# Out:
# The parameters of the line: [ 2.37500000e-02 -4.65553571e+01]

# %%
X = df['Year']
Y = df['Other']

plt.plot(X,Y)
plt.title('Annual CO2 emission from Other than Coal, Oil, Gas and Cement')
plt.xlabel('Years')
plt.ylabel('GtCO2')
plt.show()

outer = []
for i in range(len(Y)):
    for x, y in zip(X, Y):
        outer.append([x, y])

dt = np.array(outer)
x = dt[:, 0]
y = dt[:, 1]

theta = np.polyfit(x, y, 1)

print(f'The parameters of the line: {theta}')

# Now, calculating the y-axis values against x-values according to
# the parameters theta0, theta1 and theta2
y_line = theta[1] + theta[0] * x

# Plotting the data points and the best fit line
plt.scatter(x, y)
plt.plot(x, y_line, 'r')
plt.title('Annual CO2 emission from Other than Coal, Oil, Gas and Cement')
plt.xlabel('Years')
plt.ylabel('GtCO2')

plt.show()
# Out:
# The parameters of the line: [ 9.03571429e-03 -1.75382143e+01]

# %%
X = df['Year']
Y = df['Total']

plt.plot(X,Y)
plt.title('Annual CO2 emissions total')
plt.xlabel('Years')
plt.ylabel('GtCO2')
plt.show()

outer = []
for i in range(len(Y)):
    for x, y in zip(X, Y):
        outer.append([x, y])

dt = np.array(outer)
x = dt[:, 0]
y = dt[:, 1]

theta = np.polyfit(x, y, 1)

print(f'The parameters of the line: {theta}')

# Now, calculating the y-axis values against x-values according to
# the parameters theta0, theta1 and theta2
y_line = theta[1] + theta[0] * x

# Plotting the data points and the best fit line
plt.scatter(x, y)
plt.plot(x, y_line, 'r')
plt.title('Annual CO2 emissions total')
plt.xlabel('Years')
plt.ylabel('GtCO2')

plt.show()
# Out:
# The parameters of the line: [ 4.24607143e-01 -8.22123929e+02]
